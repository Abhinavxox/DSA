# %% [markdown]
# # LABSHEET 6 and 7
#
# NAME     : Abhinav Pandey
#
# ROLL NO. : AM.EN.U4AIE21088

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input("Enter the number of items: "))
val = list(map(int, input("Enter the values of the {} item(s): ".format(n)).split()))
wt = list(map(int, input("Enter the profits of the {} item(s): ".format(n)).split()))
w = int(input("Enter the capacity of the knapsack: "))

def knapsack_topdown(wt,val,w,n):
    t = [[0 for i in range(w+1)] for j in range(n+1)]
    for i in range(n+1):
        for j in range(w+1):
            if(i==0 or j==0):
                t[i][j] = 0

            elif(wt[i-1]<=j):
                t[i][j] = max(val[i-1]+t[i-1][j-wt[i-1]], t[i-1][j])

            elif(wt[i-1]>j):
                t[i][j] = t[i-1][j]

    return t[n][w]

print("Number of items: ",n)
print("Values of the items: ",val)
print("Weights of the items: ",wt)
print("The maximum profit is: ",knapsack_topdown(wt,val,w,n))
# Out:
# Number of items:  4
# Values of the items:  [2, 3, 4, 5]
# Weights of the items:  [3, 4, 5, 6]
# The maximum profit is:  5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def LIS(arr):
    n = len(arr)
    lis = [1] * n

    for i in range(1, n):
        for j in range(i):
            if arr[i] > arr[j] and lis[i] < lis[j] + 1:
                lis[i] = lis[j] + 1

    return max(lis)


# Example usage:
arr = [10, 22, 9, 33, 21, 50, 41, 60]
print("Array:", arr)
print("Length of Longest Increasing Subsequence:", LIS(arr))
# Out:
# Array: [10, 22, 9, 33, 21, 50, 41, 60]
# Length of Longest Increasing Subsequence: 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def longest_common_subsequence(X, Y):
    m = len(X)
    n = len(Y)

    dp = [[0] * (n + 1) for _ in range(m + 1)]

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if X[i - 1] == Y[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]

X = input("Enter string X: ")
Y = input("Enter string Y: ")

print("String X:", X)
print("String Y:", Y)
length = longest_common_subsequence(X, Y)
print("Length of the longest common subsequence:", length)
# Out:
# String X: ABCDEFG
# String Y: ABFG
# Length of the longest common subsequence: 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def max_product_subarray(nums):
    n = len(nums)

    # Initialize variables to track the maximum and minimum products
    max_product = nums[0]
    min_product = nums[0]
    result = nums[0]

    for i in range(1, n):
        # If the current element is negative, swap the maximum and minimum products
        if nums[i] < 0:
            max_product, min_product = min_product, max_product

        # Update the maximum and minimum products
        max_product = max(nums[i], max_product * nums[i])
        min_product = min(nums[i], min_product * nums[i])

        # Update the result if a larger product is found
        result = max(result, max_product)

    return result


# Example usage:
nums = [2, 3, -2, 4]
print("Array:", nums)
print("Product of the maximum product subarray:", max_product_subarray(nums))
# Out:
# Array: [2, 3, -2, 4]
# Product of the maximum product subarray: 6
